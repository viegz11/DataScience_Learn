# %%
import pandas as pd # Data Manupulation
import pickle # Store my model in my google Drive
import warnings #Highlight the issue
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/fiat500.csv")
df.head()
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700

# %%
df.isnull().sum()
# Out:
# ID                 0
# model              0
# engine_power       0
# age_in_days        0
# km                 0
# previous_owners    0
# lat                0
# lon                0
# price              0
# dtype: int64

# %%
list(df)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
df['previous_owners'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1520 non-null   int64
#  1   model            1520 non-null   object
#  2   engine_power     1520 non-null   int64
#  3   age_in_days      1520 non-null   int64
#  4   km               1520 non-null   int64
#  5   previous_owners  1520 non-null   int64
#  6   lat              1520 non-null   float64
#  7   lon              1520 non-null   float64
#  8   price            1520 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 107.0+ KB

# %%
df.groupby(['model']).count()
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1079          1079         1079  1079             1079  1079  1079
# pop      356           356          356   356              356   356   356
# sport     85            85           85    85               85    85    85
#
#         price
# model
# lounge   1079
# pop       356
# sport      85

# %%
df.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1520.000000   1520.000000  1520.000000    1520.000000      1520.000000
# mean    768.854605     51.915132  1657.190789   53602.474342         1.123684
# std     443.599478      4.010360  1290.870689   40181.202940         0.415901
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     383.750000     51.000000   670.000000   20000.000000         1.000000
# 50%     769.500000     51.000000  1066.000000   39162.000000         1.000000
# 75%    1151.250000     51.000000  2623.750000   80000.000000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1520.000000  1520.000000   1520.000000
# mean     43.539485    11.571552   8564.311842
# std       2.137960     2.332344   1942.771619
# min      36.855839     7.245400   2500.000000
# 25%      41.794763     9.505090   7100.000000
# 50%      44.394096    11.869260   9000.000000
# 75%      45.467960    12.786127  10000.000000
# max      46.795612    18.365520  11100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['price'], kde=True)
plt.show()

# %%
df.groupby('model')[
    ['engine_power','age_in_days','km','price']
].mean()
# Out:
#         engine_power  age_in_days             km        price
# model
# lounge     51.573679  1442.655236   47056.647822  8939.201112
# pop        52.089888  1911.101124   61482.769663  7978.851124
# sport      55.517647  3317.094118  103691.435294  6257.470588

# %%
sns.boxplot(x='model', y='price', data=df)
plt.show()

# %%
sns.countplot(x='model', data=df)
plt.show()

# %%
sns.lineplot(x="age_in_days", y="km",hue="engine_power",lw=2, data=df)
plt.show()

# %%
corr = df[['engine_power','age_in_days','km','price']].corr() # Relation betwee two columns

sns.heatmap(corr,
            annot=True,
            cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr1 = df.drop('model',axis=1).corr() # Relation betwee two columns

sns.heatmap(corr1,
            vmax=1,
            vmin=-1,
            annot=True,
            linewidths=.5,
            cmap='bwr')
# Out:
# <Axes: >

# %%
sns.scatterplot(
 x="engine_power",
 y="age_in_days",
 size="km",
 alpha=0.5,
 data=df
)
plt.show()

# %%
sns.scatterplot(
    x="previous_owners",
    y="price",
    size="km",
    hue="km",
    alpha=0.5,
    sizes=(20, 300),        # min and max marker size
    palette="viridis",      # color map
    data=df
)

plt.show()

# %%
df1 = df.drop(['lat','lon','ID'],axis=1)

# %%
df2=pd.get_dummies(df1,dtype=int)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   engine_power     1520 non-null   int64
#  1   age_in_days      1520 non-null   int64
#  2   km               1520 non-null   int64
#  3   previous_owners  1520 non-null   int64
#  4   price            1520 non-null   int64
#  5   model_lounge     1520 non-null   int64
#  6   model_pop        1520 non-null   int64
#  7   model_sport      1520 non-null   int64
# dtypes: int64(8)
# memory usage: 95.1 KB

# %% [markdown]
# Data Modeling

# %%
x = df2.drop("price", axis=1) #Input Parameters
y = df2["price"] #Output Parameters
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
y_train.shape
# Out:
# (1140,)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression #ridge, lasso
reg = LinearRegression() # creating object of LinearRegression
reg.fit(x_train,y_train) # Training and fitting LR object using training data
# Out:
# LinearRegression()

# %%
ypred=reg.predict(x_test)
ypred
# Out:
# array([ 9729.69625708,  9937.41126928,  6582.87129739, 10304.73464849,
#         9176.17250908,  6799.38502724,  9754.52809059, 10090.96606825,
#         9700.24537686,  9518.16428725,  9663.58130949,  9304.30380049,
#         9482.48354786,  8664.71972622, 10413.58499596,  7217.98392994,
#         6989.62597098,  9883.56145172,  9769.94282679,  7737.46544822,
#         4413.96033824,  5090.41695839,  9042.24962764, 10079.4991416 ,
#         9331.94014948,  8382.45531674, 10035.2280513 ,  9917.9329579 ,
#        10349.95877822,  8550.20359778, 10369.60606298, 10018.19132676,
#         8845.37070425,  9617.89517499,  5487.53162973,  8305.88591242,
#         9759.0700114 ,  9141.26020284,  8055.20465908, 10064.7716533 ,
#         6986.44184807,  7034.80950499,  5723.86516715,  9420.91716426,
#         5791.41857215,  8725.74654183,  9893.94506126, 10456.07200853,
#         6410.45019883, 10317.49422821,  6398.32484326, 10082.21952774,
#         9885.16122012,  5496.2899651 , 10075.07311145,  9832.33860952,
#         9629.09667458,  9667.26229384,  8852.29961841, 10560.3787314 ,
#         9040.298877  ,  9567.68046882,  8990.84521032, 10026.59795679,
#        10440.34616195,  9592.3781665 ,  6133.95641226,  7042.13883248,
#         5069.48482002,  7947.96895652, 10009.50383874,  9205.43795045,
#         5272.8259527 ,  6471.42775192,  7050.09360768,  6679.16202797,
#         3950.20289587, 10257.32887313,  9907.76364618,  7351.91629782,
#         5851.95568453,  7135.00361058,  6924.86921726,  9594.41083107,
#         8807.21617057,  9943.15257849,  5506.00229272, 10524.20258094,
#        10381.9670165 ,  9720.15776415,  9453.61233148,  5478.11769792,
#         8850.46438015,  6664.65453634, 10054.42502544,  7327.97139743,
#         5970.40776319,  9779.8700712 , 10126.14535911,  9313.36187954,
#         7546.04073674,  8529.61477402, 10141.24296477,  6327.61668625,
#        10094.09738588,  7958.41135634, 10167.17064949,  8114.40521115,
#         4938.10196062,  8370.06115338,  4692.17840214,  4556.60021872,
#         6504.50120262,  7231.27906561,  9955.76953714,  6983.73855184,
#         6826.65288939,  8454.32663512,  9908.89253741, 10438.69049874,
#        10271.86645703,  5887.5727654 ,  9894.64686113,  9951.50087074,
#         9207.92465197,  9856.62679647, 10073.21034472,  9833.88990139,
#         9666.20741077,  9289.07763425, 10339.53776191,  5439.86578973,
#         9867.50475213, 10033.57238809,  5170.38370939,  7351.41263032,
#         7400.02458776, 10166.587733  ,  6867.49334172, 10449.73058371,
#        10443.50540862,  9665.66261576,  9580.18306862,  9372.2203573 ,
#         7767.13120049,  8837.13480156,  8449.73475798,  5151.91007953,
#         5928.59023384,  9151.19547104, 10028.78540724,  8647.95981302,
#         9753.46741852,  8355.80769434, 10384.61581298,  5479.42460658,
#         6617.33023107,  9887.63896472, 10006.98392181, 10458.8099496 ,
#         8824.33271832, 10299.95243321, 10448.80334142,  8287.13134872,
#         6466.69244327,  9741.76376436,  4805.07289323,  8450.73182733,
#         6229.98990918,  9693.01632992,  5521.64918152,  7224.63960074,
#        10424.02055866,  9996.52675331,  5877.493943  , 10375.66009604,
#         9776.29424776,  7746.70579498,  9300.23742652,  9798.29505395,
#         6258.37427565,  7737.46544822,  7975.79476751, 10034.4645518 ,
#         7259.49374614,  7776.82855586,  5345.49052708, 10484.42294675,
#         5626.39203075,  9678.31895354, 10226.36364278,  7161.62263398,
#         6956.15716762,  7978.88710848,  6944.5729342 ,  6760.78332638,
#        10158.98775344,  9580.19809909,  9306.48447615,  8276.67942769])

# %%
y_test
# Out:
# 461      9980
# 1314     9600
# 1472     6800
# 744      9890
# 247     10500
#         ...
# 952      6800
# 1468     9980
# 478      9450
# 188     10670
# 526      7900
# Name: price, Length: 380, dtype: int64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.8342208439170529

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape # Error in the dataset

mape_value= mape(y_test, ypred)
mape_value
# Out:
# 0.07945576928196096

# %%
from sklearn.metrics import mean_squared_error as mse # Error in the mape
mse_value=mse(y_test, ypred)
mse_value**.5                                         # find square root
# Out:
# 814.8792055118192

# %%
x_test
# Out:
#       engine_power  age_in_days      km  previous_owners  model_lounge  \
# 461             51          731   36303                1             1
# 1314            51          578   32057                1             1
# 1472            51         2527  108000                1             0
# 744             51          456   17253                1             1
# 247             51         1858   12000                2             1
# ...            ...          ...     ...              ...           ...
# 952             51         2831   83000                1             0
# 1468            51          731   12000                1             1
# 478             51          790   41572                2             1
# 188             51          670   45000                1             0
# 526             51         1127   80858                1             0
#
#       model_pop  model_sport
# 461           0            0
# 1314          0            0
# 1472          1            0
# 744           0            0
# 247           0            0
# ...         ...          ...
# 952           1            0
# 1468          0            0
# 478           0            0
# 188           1            0
# 526           1            0
#
# [380 rows x 7 columns]

# %%
new=[[51,2197,70000,1,1,0,0],[51,3127,100000,1,1,0,0]]
reg.predict(new)
# Out:
# array([7862.85093123, 6526.23943706])

# %%
Results=pd.DataFrame(columns=['Price','Predicted'])
Results['Price']=y_test
Results['Predicted']=ypred
Results['Id'] = Results.index
Results['km']=x_test['km']

# %%
sns.lineplot(x='Id',y='Price',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',color='y',data=Results.head(50))
plt.show()

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.model_selection import GridSearchCV # Find the parameters
from sklearn.linear_model import Ridge

# %%
alpha = [1e-15,1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1,5,10, 20, 30]
ridge=Ridge()
parameters={'alpha':alpha}
ridge_regressor=GridSearchCV(ridge,parameters)
ridge_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 20}

# %%
ridge=Ridge(alpha=20)
ridge.fit(x_train,y_train)
ypred=ridge.predict(x_test)
ypred
# Out:
# array([ 9726.26384281,  9933.94008917,  6596.59243881, 10301.18125108,
#         9174.21759239,  6796.53282965,  9751.08393342, 10087.44451519,
#         9696.81760304,  9514.78025507,  9640.46154173,  9300.90960511,
#         9495.61839397,  8661.48555773, 10410.00933608,  7198.18770196,
#         6986.5910107 ,  9880.09826742,  9766.50578506,  7734.40819618,
#         4415.82437867,  5068.11044523,  9040.39885975, 10075.97774629,
#         9328.56991847,  8395.80836147, 10031.71506633,  9914.45827122,
#        10346.39930324,  8546.98724683, 10366.04444134, 10031.23735955,
#         8842.13242969,  9614.48834899,  5484.93771803,  8319.30313256,
#         9735.95106191,  9154.49030893,  8068.61280488, 10077.80583723,
#         6983.52257001,  7048.40179705,  5701.44782909,  9417.56890586,
#         5805.25155103,  8723.97904349,  9890.47647649, 10452.48839214,
#         6407.59898693, 10315.38620937,  6375.80868903, 10078.72273257,
#         9881.69201862,  5511.59072293, 10071.55845227,  9828.87465931,
#         9625.70107082,  9644.14977518,  8865.50242815, 10556.76858201,
#         9053.49571145,  9580.77111   ,  9004.08543495, 10023.09277736,
#        10436.7636947 ,  9588.98344163,  6131.11115343,  7055.74314782,
#         5068.36760552,  7944.85815769, 10006.00585874,  9218.65715765,
#         5254.91437842,  6485.0289839 ,  7063.72670994,  6658.64278309,
#         3928.21723483, 10253.79038567,  9904.28308494,  7348.92079106,
#         5849.19908232,  7132.06604008,  6921.91786857,  9591.00170146,
#         8365.60620838,  9919.66373726,  9933.94008917, 10011.84796835,
#         5721.09064126,  9779.95744916, 10378.9006612 ,  6254.46809694,
#         9650.80925032,  5393.96757513, 10194.08198504,  9725.59077251,
#         9395.89499214,  5089.19223684,  8852.56289125,  5817.64895496,
#         6631.91172412, 10349.6271855 ,  8134.03794857,  5862.90649874,
#         4952.09893425,  8366.8485952 ,  4707.68085456,  4534.51898324,
#         6481.91343368,  7228.34781548,  9952.28522578,  6980.78068965,
#         6840.28405962,  8467.63067915,  9905.39504219, 10435.11130376,
#        10268.32427157,  5886.2810195 ,  9891.17524673,  9948.00660866,
#         9221.1378003 ,  9853.15666796, 10086.23953095,  9830.43935228,
#         9662.78572015,  9302.27556562, 10335.97836258,  5453.76023547,
#         9864.04565225, 10030.06267539,  5167.81436958,  7364.95795608,
#         7396.98327391, 10179.59601749,  6864.51198189, 10446.14858042,
#        10441.36248459,  9662.21853073,  9576.78326042,  9388.28059211,
#         7764.07201248,  8850.41688538,  8446.54681488,  5167.32373105,
#         5925.86159496,  9164.3920555 , 10025.27691223,  8663.26308309,
#         9750.02610636,  8369.14783567, 10381.04752213,  5493.34255911,
#         6614.43761461,  9884.17198407, 10003.47554623, 10455.22563675,
#         8821.09979529, 10296.40310339, 10445.21329657,  8305.24994848,
#         6480.37590658,  9738.33103956,  4802.55729947,  8464.11220232,
#         6227.16786303,  9706.10865837,  5499.24419426,  7221.60638778,
#        10420.43681793,  9993.02103778,  5874.76726516, 10372.0940833 ,
#         9772.84998014,  7743.60443742,  9313.42709281,  9794.83691245,
#         6272.16977548,  7734.40819618,  7972.61260251, 10030.94633473,
#         7238.82136122,  7790.34117505,  5323.20300753, 10480.8321186 ,
#         5625.12754284,  9674.90521861, 10222.8330321 ,  7175.23858658,
#         6953.20071118,  7975.79925527,  6958.2610215 ,  6774.43125217,
#        10155.44613824,  9578.23863392,  9319.68358992,  8290.09846697])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.8344294648067309

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape
mape(y_test,ypred)
# Out:
# 0.07945036332560458

# %%
from sklearn.metrics import mean_squared_error as mse
mse_value=mse(y_test,ypred)
mse_value**.5
# Out:
# 814.3663112918267

# %%
new=[[51,2197,70000,1,1,0,0],[51,3127,100000,1,1,0,0]]
reg.predict(new)
# Out:
# array([7862.85093123, 6526.23943706])

# %%
Results=pd.DataFrame(columns=['Price','Predicted'])
Results['Price']=y_test
Results['Predicted']=ypred
Results['Id'] = Results.index

# %%
sns.lineplot(x='Id',y='Price',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',color='y',data=Results.head(50))
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
n_estimators=[25,50,75,100,125,150,175,200] # number of decision tree in the model
criterion=['squared_error']
max_depth=[3,5,10]
parameters={'n_estimators':n_estimators,'criterion':criterion,'max_depth':max_depth}
RFC_reg=GridSearchCV(reg,parameters)
RFC_reg.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 125, 150, 175, 200]})

# %%
RFC_reg.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 25}

# %%
rf_pred=ridge.predict(x_test)
r2_score(y_test,rf_pred)
# Out:
# 0.8344294648067309
